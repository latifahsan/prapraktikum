# %%
#IDENTITAS
print("Muhammad Latif Ahsan Jauhari") # Menampilkan Nama
print(2605060045) # Menampilkan NIM
print("Magelang, 04 Desember 2007") # Menampilkan Tempat, Tanggal lahir
print("Mungkid, Magelang, Jawa Tengah") # Menampilkan Alamat
print("Laki-laki") # Menampilkan Jenis Kelamin
print("Menonton Film") # Menampilkan Hobi
# Out:
# Muhammad Latif Ahsan Jauhari
# 2605060045
# Magelang, 04 Desember 2007
# Mungkid, Magelang, Jawa Tengah
# Laki-laki
# Menonton Film
